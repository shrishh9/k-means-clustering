# %% [markdown]
# <a href="https://colab.research.google.com/github/shrishh9/k-means-clustering/blob/main/k_means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Generate synthetic dataset for demonstration
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Plot the dataset
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.title('Generated Dataset')
plt.show()

# Initialize KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)

# Get the predicted cluster labels
y_kmeans = kmeans.predict(X)

# Plot the clusters with centroids
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.75)
plt.title('K-Means Clustering with 4 Clusters')
plt.show()

# Using Elbow method to determine the number of clusters
sse = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# Plotting the Elbow graph
plt.plot(range(1, 10), sse, 'bo-')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method for Optimal K')
plt.show()
